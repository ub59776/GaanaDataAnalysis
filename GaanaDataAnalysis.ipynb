# %%
import pandas as pd
from tqdm import tqdm

df = pd.read_csv('songs.csv')

# %%
df.head()
# Out:
#                                       name                     singer  \
# 0                    Dil - E - Nadan Tujhe  Chitra Singh|Jagjit Singh
# 1        Agar Hum Kahen Aur Woh Muskara De  Chitra Singh|Jagjit Singh
# 2                            Unke Dekhe Se               Jagjit Singh
# 3  Yeh Na Thi Hamari Qismat - Chitra Singh               Chitra Singh
# 4                  Hazaron Khwahishen Aisi               Jagjit Singh
#
#                                       singer_id duration  \
# 0  /artist/chitra-singh|/artist/jagjeet-singh-1    05:00
# 1  /artist/chitra-singh|/artist/jagjeet-singh-1    06:26
# 2                       /artist/jagjeet-singh-1    03:41
# 3                          /artist/chitra-singh    04:26
# 4                       /artist/jagjeet-singh-1    05:39
#
#                                   link language
# 0                 /dil-e-nadan-tujhe-3     Urdu
# 1  /agar-hum-kahen-aur-woh-muskura-den     Urdu
# 2                       /unke-dekhe-se     Urdu
# 3          /yeh-na-thi-hamari-qismat-2     Urdu
# 4           /hazaron-khwahishen-aisi-1     Urdu

# %%
# Checking Null Values

df.isnull().sum()
# Out:
# name         0
# singer       0
# singer_id    0
# duration     0
# link         0
# language     0
# dtype: int64

# %%
# Data Preprocess
## Dealing with Duration

duration_lst = []

for duration in df['duration']:

  m = int(duration.split(':')[0])
  s = int(duration.split(':')[1])
  sec = (m*60) + s

  duration_lst.append(sec)

df['duration'] = duration_lst

df.head(20)
# Out:
#                                                  name  \
# 0                               Dil - E - Nadan Tujhe
# 1                   Agar Hum Kahen Aur Woh Muskara De
# 2                                       Unke Dekhe Se
# 3             Yeh Na Thi Hamari Qismat - Chitra Singh
# 4                             Hazaron Khwahishen Aisi
# 5                Suna Tha Ki Woh Aayenge Anjuman Mein
# 6   Bahut Pahele Se Un Qadmon Ki Aahat Jaan Lete Hain
# 7                         Tum Itna Jo Muskura Rahe Ho
# 8                            Tum Apna Ranjhogham Apni
# 9                     Dialogues And Ishq Mujhko Nahin
# 10                       Zindagi Se Badi Saza Hi Nahi
# 11                              Kabse Hoon Kya Bataon
# 12                 Dialogue And Kabse Hoon Kya Bataon
# 13                            Hazaron Khwahishen Aisi
# 14                             Duniya Jise Kahte Hain
# 15                              Zulmat Kade Mein Mere
# 16                          Na Tha Kuchh To Khuda Tha
# 17                         Dialogues - Unke Dekhne Se
# 18                     Babul Mora Naihar Chhooto Jaye
# 19                         Manzil Na De Charagh Na De
#
#                            singer  \
# 0       Chitra Singh|Jagjit Singh
# 1       Chitra Singh|Jagjit Singh
# 2                    Jagjit Singh
# 3                    Chitra Singh
# 4                    Jagjit Singh
# 5       Chitra Singh|Jagjit Singh
# 6       Chitra Singh|Jagjit Singh
# 7                    Jagjit Singh
# 8                     Jagjit Kaur
# 9   Chitra Singh|Naseeruddin Shah
# 10                   Jagjit Singh
# 11                   Jagjit Singh
# 12  Naseeruddin Shah|Jagjit Singh
# 13                   Jagjit Singh
# 14      Chitra Singh|Jagjit Singh
# 15                   Jagjit Singh
# 16                   Jagjit Singh
# 17  Jagjit Singh|Naseeruddin Shah
# 18      Chitra Singh|Jagjit Singh
# 19      Chitra Singh|Jagjit Singh
#
#                                            singer_id  duration  \
# 0       /artist/chitra-singh|/artist/jagjeet-singh-1       300
# 1       /artist/chitra-singh|/artist/jagjeet-singh-1       386
# 2                            /artist/jagjeet-singh-1       221
# 3                               /artist/chitra-singh       266
# 4                            /artist/jagjeet-singh-1       339
# 5       /artist/chitra-singh|/artist/jagjeet-singh-1       479
# 6       /artist/chitra-singh|/artist/jagjeet-singh-1       288
# 7                            /artist/jagjeet-singh-1       321
# 8                                /artist/jagjit-kaur       189
# 9      /artist/chitra-singh|/artist/naseeruddin-shah       264
# 10                           /artist/jagjeet-singh-1       303
# 11                           /artist/jagjeet-singh-1       240
# 12  /artist/naseeruddin-shah|/artist/jagjeet-singh-1       283
# 13                           /artist/jagjeet-singh-1       339
# 14      /artist/chitra-singh|/artist/jagjeet-singh-1       449
# 15                           /artist/jagjeet-singh-1       228
# 16                           /artist/jagjeet-singh-1       204
# 17  /artist/jagjeet-singh-1|/artist/naseeruddin-shah       219
# 18      /artist/chitra-singh|/artist/jagjeet-singh-1       322
# 19      /artist/chitra-singh|/artist/jagjeet-singh-1       359
#
#                                                  link language
# 0                                /dil-e-nadan-tujhe-3     Urdu
# 1                 /agar-hum-kahen-aur-woh-muskura-den     Urdu
# 2                                      /unke-dekhe-se     Urdu
# 3                         /yeh-na-thi-hamari-qismat-2     Urdu
# 4                          /hazaron-khwahishen-aisi-1     Urdu
# 5               /suna-tha-ki-woh-aayenge-anjuman-live     Urdu
# 6   /bahut-pahele-se-un-kadmo-ki-aahat-jaan-lete-hain     Urdu
# 7                     /tum-itna-jo-muskura-rahe-ho-12     Urdu
# 8                         /tum-apna-ranjhogham-apni-1     Urdu
# 9                                       /dialogues-82     Urdu
# 10                         /tujhe-milne-ki-saza-denge     Urdu
# 11                           /kab-se-hoon-kya-bataoon     Urdu
# 12                                       /dialouge-12     Urdu
# 13                           /hazaron-khwahishen-aisi     Urdu
# 14                            /duniya-jise-kahte-hain     Urdu
# 15                             /zulmat-kade-mein-mere     Urdu
# 16                         /na-tha-kuchh-to-khuda-tha     Urdu
# 17                 /dialogues-tum-jano-tumko-gayar-se     Urdu
# 18                    /babul-mora-naihar-chhooto-jaye     Urdu
# 19                        /manzil-na-de-charagh-na-de     Urdu

# %%
# Data Analysis
## Average Duration of a song thorughout the dataset

print("Average duration of a song is", int(df['duration'].sum() / len(df['duration'])), 'seconds')
# Out:
# Average duration of a song is 295 seconds

# %%
## How many laguages of songs are there is the dataset?

len(set(df['language']))
# Out:
# 16

# %%
## What are all the languages in the dataset?

for i in set(df['language']):
  print(i)
# Out:
# Urdu
# Tamil
# Punjabi
# Bhojpuri
# Marathi
# Old
# Bengali
# Rajasthani
# Kannada
# Hindi
# Telugu
# Odia
# Gujarati
# Assamese
# Haryanvi
# Malayalam

# %%
## How many Punjabi songs are there?

c = 0

for i in df['language']:
  if (i == 'Punjabi'):
    c += 1

print('There are',c,'songs in Punjabi')
# Out:
# There are 3818 songs in Punjabi

# %%
len(df[df['language'] == 'Punjabi'])
# Out:
# 3818

# %%
## Number of songs in each Language?

for lang in df['language'].unique():
  print(lang, len(df[df['language'] == lang]))
# Out:
# Urdu 3116
# Gujarati 2115
# Tamil 4677
# Kannada 3559
# Rajasthani 541
# Haryanvi 228
# Punjabi 3818
# Hindi 4993
# Old 4993
# Malayalam 479
# Marathi 4699
# Telugu 4996
# Odia 940
# Bhojpuri 519
# Assamese 724
# Bengali 958

# %%
## Average Duration of song in each language

for lang in df['language'].unique():
  print(lang, int(df[df['language'] == lang]['duration'].mean()))
# Out:
# Urdu 407
# Gujarati 271
# Tamil 270
# Kannada 250
# Rajasthani 291
# Haryanvi 320
# Punjabi 324
# Hindi 307
# Old 307
# Malayalam 242
# Marathi 281
# Telugu 279
# Odia 257
# Bhojpuri 357
# Assamese 228
# Bengali 255

# %%
## How many unique singers are there in the dataset?

all_singer = []
for singers in df['singer']:
  all_singer += singers.split('|')

print('Total Singers : ', len(set(all_singer)))
# Out:
# Total Singers :  3940

# %%
## Who has the most number of songs?

data = []

unique_singers = list(set(all_singer))

for i in tqdm(unique_singers):

  c = 0
  for singers_ in df['singer']:
    if (i in singers_):
      c += 1

  data.append([i,c])
# Out:
# 100%|██████████| 3940/3940 [01:34<00:00, 41.58it/s]

# %%
songs = pd.DataFrame(data, columns = ['singer','songs'])

songs.sort_values(by = 'songs', ascending = False).head(10)
# Out:
#                       singer  songs
# 2411  S. P. Balasubrahmanyam   3659
# 504                    Kumar   3270
# 3546                 Susheel   3216
# 2375                Susheela   3215
# 247              P. Susheela   3213
# 2995         Lata Mangeshkar   3056
# 442              Asha Bhosle   2715
# 3206           Kishore Kumar   2401
# 1997                  Janaki   2218
# 1323               S. Janaki   2204

# %%
## Singer who played most number of songs in each language?

for lang in df['language'].unique():

  df_ = df[df['language'] == lang]
  
  all_singer = []
  for singers in df_['singer']:
    all_singer += singers.split('|')

  print(lang, len(df_),len(set(all_singer)))
# Out:
# Urdu 3116 385
# Gujarati 2115 303
# Tamil 4677 510
# Kannada 3559 379
# Rajasthani 541 218
# Haryanvi 228 76
# Punjabi 3818 636
# Hindi 4993 515
# Old 4993 515
# Malayalam 479 72
# Marathi 4699 569
# Telugu 4996 369
# Odia 940 243
# Bhojpuri 519 109
# Assamese 724 228
# Bengali 958 192
